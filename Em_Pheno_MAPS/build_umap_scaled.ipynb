# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# Load your DataFrame with your data
# Replace 'your_data.csv' with the path to your data file
df = pd.read_excel("/Users/anirudh/Desktop/Em_Pheno_MAPS/Base_mean _new.xlsx")
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#      HR-mean  O2Sat-mean  Temp-mean    SBP-mean   MAP-mean   DBP-mean  \
# 0  87.489741   96.454081  36.840836  123.334069  85.017214  68.263086
#
#    Resp-mean  EtCO2-mean  HCO3-mean  FiO2-mean  ...  Bilirubin_total-mean  \
# 0  19.185195    6.831387  23.557945   0.419681  ...              1.610752
#
#    TroponinI-mean   Hct-mean   Hgb-mean   PTT-mean  WBC-mean  Fibrinogen-mean  \
# 0        0.771652  32.848839  10.620543  37.414851  11.69324       352.363871
#
#    Platelets-mean  SOFA-mean  SIRS-mean
# 0      204.832965    3.22174   1.953424
#
# [1 rows x 31 columns]

# %%
df = df.T
df
# Out:
#                                 0
# HR-mean                 87.489741
# O2Sat-mean              96.454081
# Temp-mean               36.840836
# SBP-mean               123.334069
# MAP-mean                85.017214
# DBP-mean                68.263086
# Resp-mean               19.185195
# EtCO2-mean               6.831387
# HCO3-mean               23.557945
# FiO2-mean                0.419681
# pH-mean                  7.372655
# PaCO2-mean              38.495874
# SaO2-mean               95.642184
# Chloride-mean          102.148943
# Creatinine-mean          2.771216
# Bilirubin_direct-mean    1.347554
# Glucose-mean           138.261487
# Lactate-mean             2.073750
# Magnesium-mean           1.971139
# Phosphate-mean           3.926348
# Potassium-mean           4.111818
# Bilirubin_total-mean     1.610752
# TroponinI-mean           0.771652
# Hct-mean                32.848839
# Hgb-mean                10.620543
# PTT-mean                37.414851
# WBC-mean                11.693240
# Fibrinogen-mean        352.363871
# Platelets-mean         204.832965
# SOFA-mean                3.221740
# SIRS-mean                1.953424

# %%
reducer = umap.UMAP()

# %%
scaled_data = StandardScaler().fit_transform(df)

# %%
embedding = reducer.fit_transform(scaled_data)
embedding.shape
# Out:
# (31, 2)

# %%
embedding
# Out:
# array([[10.679954 , -2.1019313],
#        [11.217323 , -2.2943375],
#        [13.963523 ,  1.1337135],
#        [11.371053 , -1.5332438],
#        [10.439482 , -2.2564006],
#        [11.387372 , -2.177565 ],
#        [15.316704 ,  1.5327574],
#        [16.517021 ,  2.6149404],
#        [14.717228 ,  1.2579755],
#        [18.79368  ,  1.6852067],
#        [16.674713 ,  2.18181  ],
#        [13.88729  ,  0.5386883],
#        [10.850779 , -2.4764075],
#        [10.965658 , -1.8457482],
#        [17.781628 ,  2.6133723],
#        [18.235989 ,  1.7263157],
#        [11.532142 , -1.2986207],
#        [18.12155  ,  2.234403 ],
#        [18.445187 ,  2.7290337],
#        [17.248125 ,  2.960091 ],
#        [17.345821 ,  2.582883 ],
#        [18.866907 ,  2.4653857],
#        [18.44242  ,  1.4135301],
#        [14.213679 ,  0.8199643],
#        [16.427856 ,  1.7711545],
#        [13.68903  ,  0.6574652],
#        [16.063457 ,  1.9870769],
#        [11.104763 , -1.1179796],
#        [10.875718 , -1.3290977],
#        [17.569653 ,  2.3432808],
#        [18.547039 ,  2.1746566]], dtype=float32)

# %%
plt.figure(figsize=(10, 8))
plt.scatter(embedding[:, 0], embedding[:, 1], s=10, cmap='viridis')
plt.title('UMAP Visualization')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()
# Out:
# /var/folders/m1/b8h0__9519gdz_f9pqrq323h0000gn/T/ipykernel_63114/47261342.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(embedding[:, 0], embedding[:, 1], s=10, cmap='viridis')
